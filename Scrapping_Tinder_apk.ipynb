# %% [markdown]
# ## Scrapping Datasets Apk Tinder

# %% [markdown]
# Tinder adalah aplikasi kencan yang memungkinkan pengguna untuk saling berkenalan melalui sistem "swipe" di mana pengguna bisa menunjukkan minat atau tidak terhadap profil lain. Aplikasi ini menghubungkan orang berdasarkan lokasi dan preferensi tertentu, memungkinkan interaksi hanya jika kedua belah pihak saling menyukai.
#
# Saya tertarik untuk menganalisis pengalaman para pengguna di Indonesia melalui ulasan mereka. Melihat ulasan dari perspektif lokal bisa memberikan wawasan unik tentang bagaimana Tinder digunakan di Indonesia, termasuk persepsi budaya, ekspektasi, serta pengalaman pengguna dalam berinteraksi melalui aplikasi ini.

# %%
# Mendonwload api scrapper Google Play
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd

# %%
# Mengambil semua ulasan dari aplikasi dengan ID 'com.tinder' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview,_ = reviews(
    'com.tinder',       # ID aplikasi
    lang='id',              # Bahasa ulasan (default: 'en')
    country='id',           # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=11000,            # Jumlah maksimum ulasan yang ingin diambil
    filter_score_with = None # Jumlah seluruh rating score (default: None, means all score)
)

# %%
# Menyusun hasil scrapping menjadi dataframe
df_tinder = pd.DataFrame(scrapreview)
df_tinder.head()
# Out:
#                                reviewId         userName  \
# 0  07bb2adf-dfb2-4ac5-bed5-5a995eefe8a8  Pengguna Google
# 1  042c7b30-9e5b-4aa5-823a-8a5f467cf773  Pengguna Google
# 2  258c4a11-aaf1-408a-869d-8fb88e52674b  Pengguna Google
# 3  c38793ec-dd36-4253-acd3-9a60253b95e9  Pengguna Google
# 4  85e31922-0dd8-4d62-b913-c36ee617ea7d  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Nge bug mulu.. Parah!! Mau log in susah, mau b...      1              0
# 1  Aplikasi sangat jelek sekali, sudah topup tpi ...      2              3
# ...

# %%
df_tinder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              11000 non-null  object
#  1   userName              11000 non-null  object
#  2   userImage             11000 non-null  object
#  3   content               11000 non-null  object
#  4   score                 11000 non-null  int64
#  5   thumbsUpCount         11000 non-null  int64
#  6   reviewCreatedVersion  7656 non-null   object
#  7   at                    11000 non-null  datetime64[ns]
#  8   replyContent          350 non-null    object
#  9   repliedAt             350 non-null    datetime64[ns]
#  10  appVersion            7656 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 945.4+ KB

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Mengunduh dataset hasil scrapping
df_tinder.to_csv("/content/gdrive/MyDrive/Learn/DATA SCIENCE/raw_df_tinder10k.csv")

# %%
# Mengunduh dataset hasil scrapping
df_tinder.to_csv("raw_df_tinder10k.csv", index=False)
